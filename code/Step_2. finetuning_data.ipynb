# %%
import pandas as pd

# %%
fine_data = pd.read_pickle('./fine_data_last.pkl')

# %%
fine_data
# Out:
#      LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_4  PAY_5  PAY_6  BILL_AMT4  \
# 0       100000    2          1         1   30      0      0      0          0
# 1       140000    2          1         2   32      0      0      2     105575
# 2        30000    2          2         3   35      0      0      0      28628
# 3       210000    2          1         2   27      0      0      0       1554
# 4        50000    1          2         2   25      2      4      3      47242
# ..         ...  ...        ...       ...  ...    ...    ...    ...        ...
# 495     100000    2          1         2   28      0      0      0      85786
# 496      50000    1          3         1   41      2      0      0      28444
# 497     110000    1          1         2   33      0      0      0      61123
# 498      10000    1          3         3   40      0      0      0      10000
# 499     200000    2          2         1   61      0      0      0        387
#
#      BILL_AMT5  BILL_AMT6  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0            0       2994         0      2995         0
# 1       122173     116266     20000         0      9010
# 2        29005      29817       764      1000       850
# 3         5705       6386      5705      2000         0
# 4        46212      45205         0         0         0
# ..         ...        ...       ...       ...       ...
# 495      65345      67205      3000      3000      3000
# 496      28878      27655      1100      1100      2000
# 497      59395      52189      3027      3000      2500
# 498          0          0         0         0         0
# 499          0       4540         0      4543      1386
#
#      default.payment.next.month
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
# ..                          ...
# 495                           0
# 496                           0
# 497                           0
# 498                           0
# 499                           0
#
# [1000 rows x 15 columns]

# %%
new_column_names = {
    'LIMIT_BAL': 'Amount of given credit in NT dollars',
    'SEX': 'Gender',
    'EDUCATION': 'Education',
    'MARRIAGE': 'Marital status',
    'AGE': 'Age',
    # 'PAY_0': 'Repayment status in September, 2005',
    # 'PAY_2': 'Repayment status in August, 2005',
    # 'PAY_3': 'Repayment status in July, 2005',
    'PAY_4': 'Repayment status in June, 2005',
    'PAY_5': 'Repayment status in May, 2005',
    'PAY_6': 'Repayment status in April, 2005',
    # 'BILL_AMT1': 'Amount of bill statement in September, 2005',
    # 'BILL_AMT2': 'Amount of bill statement in August, 2005',
    # 'BILL_AMT3': 'Amount of bill statement in July, 2005',
    'BILL_AMT4': 'Amount of bill statement in June, 2005',
    'BILL_AMT5': 'Amount of bill statement in May, 2005',
    'BILL_AMT6': 'Amount of bill statement in April, 2005',
    # 'PAY_AMT1': 'Amount of previous payment in September, 2005',
    # 'PAY_AMT2': 'Amount of previous payment in August, 2005',
    # 'PAY_AMT3': 'Amount of previous payment in July, 2005',
    'PAY_AMT4': 'Amount of previous payment in June, 2005',
    'PAY_AMT5': 'Amount of previous payment in May, 2005',
    'PAY_AMT6': 'Amount of previous payment in April, 2005',
    'default.payment.next.month': 'Default Payment Next Month'
}

fine_data = fine_data.rename(columns=new_column_names)

# %%
fine_data_input = fine_data.drop(columns=['Default Payment Next Month'])
fine_data_output = fine_data[['Default Payment Next Month']].replace({1: 'Yes, this customer will default on his/her credit card payment. ', 0: 'No, this  customer will not default on his/her credit card payment.'})

# %%
def tab_to_str(row):
    output = ""
    for col, val in row.items():
        output += f"{col}: {val}\n"
    return output[:-1]


tab_to_str_input_list = []
for index, row in fine_data_input.iterrows():
    tab_to_str_input_list.append(tab_to_str(row))

# %%
tab_to_str_input_list_df = pd.DataFrame(tab_to_str_input_list, columns=["list"])

# %%
fine_data_output = fine_data_output.reset_index(drop=True)

# %%
final_data = pd.concat([tab_to_str_input_list_df, fine_data_output], axis=1)

# %%
final_data["Default Payment Next Month"][0]
# Out:
# 'Yes, this customer will default on his/her credit card payment. '

# %%
print(final_data["list"][0])
# Out:
# Amount of given credit in NT dollars: 100000
# Gender: 2
# Education: 1
# Marital status: 1
# Age: 30
# Repayment status in June, 2005: 0
# Repayment status in May, 2005: 0
# Repayment status in April, 2005: 0
# Amount of bill statement in June, 2005: 0
# Amount of bill statement in May, 2005: 0
# Amount of bill statement in April, 2005: 2994
# Amount of previous payment in June, 2005: 0
# Amount of previous payment in May, 2005: 2995
# Amount of previous payment in April, 2005: 0

# %%
final_data["Default Payment Next Month"]
# Out:
# 0      Yes, this customer will default on his/her cre...
# 1      Yes, this customer will default on his/her cre...
# 2      Yes, this customer will default on his/her cre...
# 3      Yes, this customer will default on his/her cre...
# 4      Yes, this customer will default on his/her cre...
#                              ...
# 995    No, this  customer will not default on his/her...
# 996    No, this  customer will not default on his/her...
# 997    No, this  customer will not default on his/her...
# 998    No, this  customer will not default on his/her...
# 999    No, this  customer will not default on his/her...
# Name: Default Payment Next Month, Length: 1000, dtype: object

# %%
# system_prompt = "You are a helpful AI assistant for financial and  commercial analysis"

# user_prompt = f"""when the customer's conditions are as follows:
# {final_data["list"]}
# Will the customer be late on October 2005 payment?"""

# base_prompt = f"<|begin_of_text|><|start_header_id|>system<|end_header_id|>{system_prompt}<|eot_id|><|start_header_id|>user<|end_header_id|>{user_prompt}<|eot_id|><|start_header_id|>assistant<|end_header_id|>"

# %%
def generate_prompt(row):
    input = row["list"]
    output = row["Default Payment Next Month"]

    system_prompt = "You are a helpful AI assistance for financial and commercial analysis"
    user_prompt = f"when the customer's conditions are as follows:\n{input}\nWill the customer be late on October 2005 payment?"



    base_prompt = f"<|begin_of_text|><|start_header_id|>system<|end_header_id|>\n{system_prompt}<|eot_id|>\n<|start_header_id|>user<|end_header_id|>\n{user_prompt}<|eot_id|><|start_header_id|>assistant<|end_header_id|>\n{output}<|eot_id|>"
    
    return base_prompt

# %%
final_data
# Out:
#                                                   list  \
# 0    Amount of given credit in NT dollars: 100000\n...
# 1    Amount of given credit in NT dollars: 140000\n...
# 2    Amount of given credit in NT dollars: 30000\nG...
# 3    Amount of given credit in NT dollars: 210000\n...
# 4    Amount of given credit in NT dollars: 50000\nG...
# ..                                                 ...
# 995  Amount of given credit in NT dollars: 100000\n...
# 996  Amount of given credit in NT dollars: 50000\nG...
# 997  Amount of given credit in NT dollars: 110000\n...
# 998  Amount of given credit in NT dollars: 10000\nG...
# 999  Amount of given credit in NT dollars: 200000\n...
#
#                             Default Payment Next Month
# 0    Yes, this customer will default on his/her cre...
# 1    Yes, this customer will default on his/her cre...
# 2    Yes, this customer will default on his/her cre...
# 3    Yes, this customer will default on his/her cre...
# 4    Yes, this customer will default on his/her cre...
# ..                                                 ...
# 995  No, this  customer will not default on his/her...
# 996  No, this  customer will not default on his/her...
# 997  No, this  customer will not default on his/her...
# 998  No, this  customer will not default on his/her...
# 999  No, this  customer will not default on his/her...
#
# [1000 rows x 2 columns]

# %%
# Apply the function to each row in the DataFrame
final_data["prompt"] = final_data.apply(generate_prompt, axis=1)

# %%
# Apply the function to each row in the DataFrame
final_data["prompt"] = final_data.apply(generate_prompt, axis=1)

# %%
print(final_data["prompt"][0])
# Out:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
# You are a helpful AI assistance for financial and commercial analysis<|eot_id|>
# <|start_header_id|>user<|end_header_id|>
# when the customer's conditions are as follows:
# Amount of given credit in NT dollars: 100000
# Gender: 2
# Education: 1
# Marital status: 1
# Age: 30
# Repayment status in June, 2005: 0
# Repayment status in May, 2005: 0
# Repayment status in April, 2005: 0
# Amount of bill statement in June, 2005: 0
# Amount of bill statement in May, 2005: 0
# Amount of bill statement in April, 2005: 2994
# Amount of previous payment in June, 2005: 0
# Amount of previous payment in May, 2005: 2995
# Amount of previous payment in April, 2005: 0
# Will the customer be late on October 2005 payment?<|eot_id|><|start_header_id|>assistant<|end_header_id|>
# Yes, this customer will default on his/her credit card payment. <|eot_id|>

# %%
final_data.to_pickle('./finetuning_data.pkl')
